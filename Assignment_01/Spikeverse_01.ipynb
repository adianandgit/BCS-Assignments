# %% [markdown]
# # Task 01

# %% [markdown]
# ### Q-Table Initialization:

# %%
import numpy as np

def init_q_table(n_states, n_actions):
    return np.zeros((n_states, n_actions))

# %% [markdown]
# __it returns a 2-D array of size (number of states)*(number of actions)... intially each element of table is assigned 0 later with Q update method we try to reach the optimal policy by which our agent would behave__

# %% [markdown]
# ### Q-Table Update Function

# %%
def q_update(Q, s, a, r, s_next, alpha, gamma):
    Q[s, a] = Q[s, a] + alpha * (r + gamma * np.max(Q[s_next]) - Q[s, a])
    return Q

# %% [markdown]
# __As mentioned above, this is the rule for updating the Q table with subsequent episodes, gamma determines the dependence of action on future rewards__

# %% [markdown]
# # Task 02 ε-Greedy Policy on a Custom GridWorld

# %% [markdown]
# ### GridWorld Definition:

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

''' --------------------------------
 GridWorld Environment
 ----------------------------------'''
class GridWorld:
    def __init__(self):
        self.grid_size = 4
        self.terminal_states = {(0, 3): 1.0, (1, 3): -1.0}
        self.start_state = (3, 0)
        self.state = self.start_state

    def reset(self):
        self.state = self.start_state
        return self.state

    def step(self, action):
        row, col = self.state
        if self.state in self.terminal_states:
            return self.state, 0.0, True

        # Move agent
        if action == 0 and row > 0: row -= 1        # up
        elif action == 1 and row < 3: row += 1      # down
        elif action == 2 and col > 0: col -= 1      # left
        elif action == 3 and col < 3: col += 1      # right

        self.state = (row, col)

        reward = self.terminal_states.get(self.state, -0.01)
        done = self.state in self.terminal_states
        return self.state, reward, done

    def get_state_space(self):
        return [(i, j) for i in range(self.grid_size) for j in range(self.grid_size)]

# %% [markdown]
# ### ε-Greedy Action Selection:

# %%
def select_action(Q, state, epsilon):
    if random.random() < epsilon:
        return random.choice(range(4))
    else:
        return np.argmax(Q[state])

# %% [markdown]
# ### Training and Evaluation:

# %%
def train_agent(epsilon):
    env = GridWorld()
    state_space = env.get_state_space()
    state_to_idx = {s: i for i, s in enumerate(state_space)}
    Q = np.zeros((len(state_space), 4))

    episodes = 500
    alpha = 0.1
    gamma = 0.99
    total_rewards = []

    for ep in range(episodes):
        state = env.reset()
        total_reward = 0
        done = False

        while not done:
            s_idx = state_to_idx[state]
            action = select_action(Q, s_idx, epsilon)
            next_state, reward, done = env.step(action)
            ns_idx = state_to_idx[next_state]

            Q[s_idx, action] += alpha * (reward + gamma * np.max(Q[ns_idx]) - Q[s_idx, action])

            state = next_state
            total_reward += reward

        total_rewards.append(total_reward)

    # first plot--- toal rewards over episodes
    plt.figure(figsize=(10, 4))
    plt.plot(total_rewards, label='Total Reward per Episode')
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Total Rewards over Episodes')
    plt.legend()
    plt.grid(True)
    plt.show()

    # second plot-- moving average of total rewards
    window_size = 20
    moving_avg = np.convolve(total_rewards, np.ones(window_size)/window_size, mode='valid')

    plt.figure(figsize=(10, 4))
    plt.plot(moving_avg, color='orange', label=f'{window_size}-Episode Moving Average')
    plt.xlabel('Episode')
    plt.ylabel('Average Reward')
    plt.title('Moving Average of Total Rewards')
    plt.legend()
    plt.grid(True)
    plt.show()

    return total_rewards

# Call the function to run training and see the plots
rewardss=train_agent(epsilon=0.1)
# Out:
# Error: name 'GridWorld' is not defined

# %% [markdown]
# # Task 3: Experience Replay Buffer

# %% [markdown]
# ### Replay Buffer Implementation:

# %%
import random

class ReplayBuffer:
    def __init__(self, capacity):
        self.capacity = capacity
        self.buffer = []
        self.position = 0 
    ####TRACKS TO THE NEXT POSITION OF INSERT

    def push(self, state, action, reward, next_state, done):
        transition = (state, action, reward, next_state, done)
        if len(self.buffer) < self.capacity:
            self.buffer.append(transition)
        else:
            
            self.buffer[self.position] = transition #--->OVERRIDE THE OLDEST TRANSITION WHEN BUFFER IS FULL
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        return (np.array(states),
                np.array(actions),
                np.array(rewards, dtype=np.float32),
                np.array(next_states),
                np.array(dones, dtype=np.bool_))

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# ### Buffer Demonstration:

# %%
buffer = ReplayBuffer(capacity=100)

'''------------------
FILLING THE BUFFER WITH 100 RANDOM TRANSITION
---------------------'''
for _ in range(100):
    state = np.random.randint(0, 10)        # random int state
    action = np.random.randint(0, 4)        # random int action (say 4 possible actions)
    reward = np.random.uniform(-1, 1)       # random float reward between -1 and 1
    next_state = np.random.randint(0, 10)   # random int next_state
    done = random.choice([True, False])     # random done flag
    buffer.push(state, action, reward, next_state, done)

""""-------------------
SAMPLING A BATCH OF 32 TRANSITIONS FROM BUFFER
---------------------"""
states, actions, rewards, next_states, dones = buffer.sample(32)

#-------> Print shapes and types
print("States shape:", states.shape, ", dtype:", states.dtype)
print("Actions shape:", actions.shape, ", dtype:", actions.dtype)
print("Rewards shape:", rewards.shape, ", dtype:", rewards.dtype)
print("Next_states shape:", next_states.shape, ", dtype:", next_states.dtype)
print("Dones shape:", dones.shape, ", dtype:", dones.dtype)
# Out:
# States shape: (32,) , dtype: int64
#
# Actions shape: (32,) , dtype: int64
#
# Rewards shape: (32,) , dtype: float32
#
# Next_states shape: (32,) , dtype: int64
#
# Dones shape: (32,) , dtype: bool

# %% [markdown]
# # Task 4: Deep Q-Network with Target Copy

# %% [markdown]
# ### DQN Network Architectures:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# ----------------------------------------
# DQNPolicy: Defines the policy network
# ----------------------------------------

class DQNPolicy(nn.Module):
    def __init__(self, input_dim, output_dim):

        super(DQNPolicy, self).__init__()

        # First fully connected layer (input -> 128 neurons)
        self.fc1 = nn.Linear(input_dim, 128)

        # Second fully connected layer (128 -> 128 neurons)
        self.fc2 = nn.Linear(128, 128)

        # Output layer (128 -> number of actions)
        self.out = nn.Linear(128, output_dim)

    def forward(self, x):
        """
        Forward pass for computing Q-values for each action.
        """
        x = F.relu(self.fc1(x))  # Apply ReLU activation after fc1
        x = F.relu(self.fc2(x))  # Apply ReLU activation after fc2
        return self.out(x)       # Output raw Q-values (no activation),

# %% [markdown]
# ### DQN Target Network: Same architecture as policy network

# %%
class DQNTarget(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(DQNTarget, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.out = nn.Linear(128, output_dim)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.out(x)

# %% [markdown]
# ### Target Network Update:

# %%
def update_target(policy_net, target_net):
    target_net.load_state_dict(policy_net.state_dict())

# %% [markdown]
# it copies the weights from the policy network to the target network.
# it helps to stabalize the training by keeping a few steps
#
# Args---->
# policy_net (nn.Module): The main policy network being trained.
# target_net (nn.Module): The target network to be updated.

# %% [markdown]
# # Task 05: Full DQN Training Loop on CartPole-v1

# %% [markdown]
# ### Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import random
from collections import namedtuple, deque
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import matplotlib.pyplot as plt

# %% [markdown]
# Importiing all the necessary libraries

# %%
class QNetwork(nn.Module):
    def __init__(self, state_size, action_size, seed, fc1_units=64, fc2_units=64):
        super(QNetwork, self).__init__()
        self.seed = torch.manual_seed(seed)
        
        self.fc1 = nn.Linear(state_size, fc1_units)
        self.fc2 = nn.Linear(fc1_units, fc2_units)
        self.fc3 = nn.Linear(fc2_units, action_size)
       
        self.to(device)
    '''-----------------------------------------------------------------------
    ADDING THREE NN LAYERS FOR TRAINING
    ---------------------------------------------------------------------------'''
    def forward(self, state):
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        return self.fc3(x)
    '''-----------------------------------------------------------------------
    
    ---------------------------------------------------------------------------'''

# %% [markdown]
# #### Replay buffer: stores the experience tuples

# %%
class ReplayBuffer:
    def __init__(self, action_size, buffer_size, batch_size, seed):
        self.action_size = action_size
        
        self.memory = deque(maxlen=buffer_size)
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        
        self.seed = random.seed(seed)
    """
    PARAMETERS:
    - action_size (int): Number of possible actions
    - buffer_size (int): Maximum size of the buffer
    - batch_size (int): Number of samples to retrieve for training
    - seed (int): Random seed
    """
    def add(self, state, action, reward, next_state, done):
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)

    def sample(self):
        experiences = random.sample(self.memory, k=self.batch_size)

        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(device)
        
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)

        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# #### DQNAgent – The Deep Q-Learning Agent

# %%
class DQNAgent:
    # Initialize the DQN agent
    def __init__(self, state_size, action_size, seed, lr):
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)


        self.qnetwork_local = QNetwork(state_size, action_size, seed).to(device)#--->POLICY NETWORK
        self.qnetwork_target = QNetwork(state_size, action_size, seed).to(device)#---->TARGET NETWORK


        self.optimizer = optim.Adam(self.qnetwork_local.parameters(), lr) #used adam optimizer as plain SGD has slower convergence
        self.memory = ReplayBuffer(action_size, buffer_size=int(1e5), batch_size=64, seed=seed)
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        self.memory.add(state, action, reward, next_state, done)

        self.t_step = (self.t_step + 1) % 4
        if self.t_step == 0:
            if len(self.memory) > 64:
                experiences = self.memory.sample()
                self.learn(experiences, gamma=0.99)

    # Choose an action based on the current state
    def act(self, state, eps=0.):
        state_tensor = torch.from_numpy(state).float().unsqueeze(0).to(device)
        
        self.qnetwork_local.eval()
        with torch.no_grad():
            action_values = self.qnetwork_local(state_tensor)
        self.qnetwork_local.train()

        if np.random.random() > eps:
            return action_values.argmax(dim=1).item()
        else:
            return np.random.randint(self.action_size)
        
    def update_target(self):
        self.qnetwork_target.load_state_dict(self.qnetwork_local.state_dict())


    # Learn from batch of experiences
    def learn(self, experiences, gamma):
        states, actions, rewards, next_states, dones = experiences  # already unpacked tensors

        Q_targets_next = self.qnetwork_target(next_states).detach().max(1)[0].unsqueeze(1)
        Q_targets = rewards + (gamma * Q_targets_next * (1 - dones))

        Q_expected = self.qnetwork_local(states).gather(1, actions)

        loss = F.mse_loss(Q_expected, Q_targets)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.soft_update(self.qnetwork_local, self.qnetwork_target, tau=1e-2)


    def soft_update(self, local_model, target_model, tau):
        for target_param, local_param in zip(target_model.parameters(), local_model.parameters()):
            target_param.data.copy_(tau * local_param.data + (1.0 - tau) * target_param.data)

# %% [markdown]
# ### Training Loop: (N, M and X are hyperparameters)

# %%
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

#-> Set up the environment
env = gym.make("CartPole-v1")
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

N = 700
M = 0.0015
X = 5

#-> Training configuration
max_steps = 200
epsilon_start = 1.0
epsilon_end = 0.01
learning_rate = 0.00025
gamma = 0.99

#-> Initialize the DQN agent
agent = DQNAgent(state_size=state_dim, action_size=action_dim, seed=170715, lr=learning_rate)

# Track rewards and success
episode_rewards = []
success_count = 0

#-> Helper for moving average plot
def moving_average(data, window=20):
    return np.convolve(data, np.ones(window) / window, mode='valid')

# Main training loop
for episode in range(N):
    state, _ = env.reset()
    epsilon = max(epsilon_end, epsilon_start - M * episode)
    total_reward = 0

    for _ in range(max_steps):
        action = agent.act(state, eps=epsilon)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        agent.step(state, action, reward, next_state, done)

        state = next_state
        total_reward += reward
        if done:
            break

    episode_rewards.append(total_reward)

    if total_reward >= 195:
        success_count += 1

    # Logging progress
    if (episode + 1) % X == 0:
        avg_reward = np.mean(episode_rewards[-100:])
        success_rate = (success_count / (episode + 1)) * 100
        print(f"Episode {episode + 1:>3} | Avg Reward (last 100): {avg_reward:.2f} | Success Rate: {success_rate:.1f}%")

# Plotting rewards over time
plt.figure(figsize=(10, 5))
plt.plot(moving_average(episode_rewards), label="Moving Average (window=20)", linewidth=2)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Training Progress - DQN on CartPole-v1")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Final success summary
final_success_rate = (success_count / num_episodes) * 100
print(f"\nFinal Success Rate: {final_success_rate:.2f}% ({success_count} out of {num_episodes} episodes)")
# Out:
# Episode   5 | Avg Reward (last 100): 17.60 | Success Rate: 0.0%
#
# Episode  10 | Avg Reward (last 100): 18.80 | Success Rate: 0.0%
#
# Episode  15 | Avg Reward (last 100): 20.53 | Success Rate: 0.0%
#
# Episode  20 | Avg Reward (last 100): 21.75 | Success Rate: 0.0%
#
# Episode  25 | Avg Reward (last 100): 22.00 | Success Rate: 0.0%
#
# Episode  30 | Avg Reward (last 100): 23.03 | Success Rate: 0.0%
#
# Episode  35 | Avg Reward (last 100): 22.17 | Success Rate: 0.0%
#
# Episode  40 | Avg Reward (last 100): 21.90 | Success Rate: 0.0%
#
# Episode  45 | Avg Reward (last 100): 21.84 | Success Rate: 0.0%
#
# Episode  50 | Avg Reward (last 100): 22.24 | Success Rate: 0.0%
#
# Episode  55 | Avg Reward (last 100): 21.76 | Success Rate: 0.0%
#
# Episode  60 | Avg Reward (last 100): 21.37 | Success Rate: 0.0%
#
# Episode  65 | Avg Reward (last 100): 21.05 | Success Rate: 0.0%
#
# Episode  70 | Avg Reward (last 100): 21.13 | Success Rate: 0.0%
#
# Episode  75 | Avg Reward (last 100): 21.32 | Success Rate: 0.0%
#
# Episode  80 | Avg Reward (last 100): 21.64 | Success Rate: 0.0%
#
# Episode  85 | Avg Reward (last 100): 21.48 | Success Rate: 0.0%
#
# Episode  90 | Avg Reward (last 100): 21.32 | Success Rate: 0.0%
#
# Episode  95 | Avg Reward (last 100): 21.09 | Success Rate: 0.0%
#
# Episode 100 | Avg Reward (last 100): 21.69 | Success Rate: 0.0%
#
# Episode 105 | Avg Reward (last 100): 21.88 | Success Rate: 0.0%
#
# Episode 110 | Avg Reward (last 100): 21.62 | Success Rate: 0.0%
#
# Episode 115 | Avg Reward (last 100): 21.05 | Success Rate: 0.0%
#
# Episode 120 | Avg Reward (last 100): 20.63 | Success Rate: 0.0%
#
# Episode 125 | Avg Reward (last 100): 20.50 | Success Rate: 0.0%
#
# Episode 130 | Avg Reward (last 100): 20.52 | Success Rate: 0.0%
#
# Episode 135 | Avg Reward (last 100): 21.14 | Success Rate: 0.0%
#
# Episode 140 | Avg Reward (last 100): 21.10 | Success Rate: 0.0%
#
# Episode 145 | Avg Reward (last 100): 21.06 | Success Rate: 0.0%
#
# Episode 150 | Avg Reward (last 100): 20.94 | Success Rate: 0.0%
#
# Episode 155 | Avg Reward (last 100): 21.22 | Success Rate: 0.0%
#
# Episode 160 | Avg Reward (last 100): 21.47 | Success Rate: 0.0%
#
# Episode 165 | Avg Reward (last 100): 22.00 | Success Rate: 0.0%
#
# Episode 170 | Avg Reward (last 100): 22.53 | Success Rate: 0.0%
#
# Episode 175 | Avg Reward (last 100): 22.53 | Success Rate: 0.0%
#
# Episode 180 | Avg Reward (last 100): 23.04 | Success Rate: 0.0%
#
# Episode 185 | Avg Reward (last 100): 24.10 | Success Rate: 0.0%
#
# Episode 190 | Avg Reward (last 100): 24.44 | Success Rate: 0.0%
#
# Episode 195 | Avg Reward (last 100): 25.06 | Success Rate: 0.0%
#
# Episode 200 | Avg Reward (last 100): 25.00 | Success Rate: 0.0%
#
# Episode 205 | Avg Reward (last 100): 25.53 | Success Rate: 0.0%
#
# Episode 210 | Avg Reward (last 100): 26.54 | Success Rate: 0.0%
#
# Episode 215 | Avg Reward (last 100): 27.15 | Success Rate: 0.0%
#
# Episode 220 | Avg Reward (last 100): 28.20 | Success Rate: 0.0%
#
# Episode 225 | Avg Reward (last 100): 28.97 | Success Rate: 0.0%
#
# Episode 230 | Avg Reward (last 100): 29.81 | Success Rate: 0.0%
#
# Episode 235 | Avg Reward (last 100): 30.34 | Success Rate: 0.0%
#
# Episode 240 | Avg Reward (last 100): 32.38 | Success Rate: 0.0%
#
# Episode 245 | Avg Reward (last 100): 34.68 | Success Rate: 0.0%
#
# Episode 250 | Avg Reward (last 100): 37.16 | Success Rate: 0.0%
#
# Episode 255 | Avg Reward (last 100): 38.72 | Success Rate: 0.0%
#
# Episode 260 | Avg Reward (last 100): 40.42 | Success Rate: 0.0%
#
# Episode 265 | Avg Reward (last 100): 40.80 | Success Rate: 0.0%
#
# Episode 270 | Avg Reward (last 100): 40.84 | Success Rate: 0.0%
#
# Episode 275 | Avg Reward (last 100): 42.05 | Success Rate: 0.0%
#
# Episode 280 | Avg Reward (last 100): 41.87 | Success Rate: 0.0%
#
# Episode 285 | Avg Reward (last 100): 44.08 | Success Rate: 0.0%
#
# Episode 290 | Avg Reward (last 100): 45.42 | Success Rate: 0.0%
#
# Episode 295 | Avg Reward (last 100): 47.03 | Success Rate: 0.0%
#
# Episode 300 | Avg Reward (last 100): 49.83 | Success Rate: 0.0%
#
# Episode 305 | Avg Reward (last 100): 50.92 | Success Rate: 0.0%
#
# Episode 310 | Avg Reward (last 100): 54.32 | Success Rate: 0.0%
#
# Episode 315 | Avg Reward (last 100): 56.97 | Success Rate: 0.0%
#
# Episode 320 | Avg Reward (last 100): 60.29 | Success Rate: 0.0%
#
# Episode 325 | Avg Reward (last 100): 64.55 | Success Rate: 0.3%
#
# Episode 330 | Avg Reward (last 100): 66.08 | Success Rate: 0.3%
#
# Episode 335 | Avg Reward (last 100): 69.83 | Success Rate: 0.3%
#
# Episode 340 | Avg Reward (last 100): 71.78 | Success Rate: 0.6%
#
# Episode 345 | Avg Reward (last 100): 73.55 | Success Rate: 0.6%
#
# Episode 350 | Avg Reward (last 100): 76.22 | Success Rate: 0.9%
#
# Episode 355 | Avg Reward (last 100): 79.30 | Success Rate: 0.8%
#
# Episode 360 | Avg Reward (last 100): 79.89 | Success Rate: 0.8%
#
# Episode 365 | Avg Reward (last 100): 84.30 | Success Rate: 1.1%
#
# Episode 370 | Avg Reward (last 100): 90.10 | Success Rate: 1.6%
#
# Episode 375 | Avg Reward (last 100): 94.33 | Success Rate: 1.9%
#
# Episode 380 | Avg Reward (last 100): 100.02 | Success Rate: 2.4%
#
# Episode 385 | Avg Reward (last 100): 103.97 | Success Rate: 2.9%
#
# Episode 390 | Avg Reward (last 100): 109.43 | Success Rate: 3.3%
#
# Episode 395 | Avg Reward (last 100): 114.09 | Success Rate: 3.8%
#
# Episode 400 | Avg Reward (last 100): 117.91 | Success Rate: 4.8%
#
# Episode 405 | Avg Reward (last 100): 123.70 | Success Rate: 5.4%
#
# Episode 410 | Avg Reward (last 100): 126.60 | Success Rate: 5.9%
#
# Episode 415 | Avg Reward (last 100): 132.47 | Success Rate: 6.7%
#
# Episode 420 | Avg Reward (last 100): 136.44 | Success Rate: 7.4%
#
# Episode 425 | Avg Reward (last 100): 140.39 | Success Rate: 8.5%
#
# Episode 430 | Avg Reward (last 100): 145.46 | Success Rate: 8.8%
#
# Episode 435 | Avg Reward (last 100): 147.48 | Success Rate: 9.2%
#
# Episode 440 | Avg Reward (last 100): 151.85 | Success Rate: 9.8%
#
# Episode 445 | Avg Reward (last 100): 155.29 | Success Rate: 10.3%
#
# Episode 450 | Avg Reward (last 100): 158.97 | Success Rate: 11.3%
#
# Episode 455 | Avg Reward (last 100): 162.45 | Success Rate: 12.1%
#
# Episode 460 | Avg Reward (last 100): 169.06 | Success Rate: 13.0%
#
# Episode 465 | Avg Reward (last 100): 172.79 | Success Rate: 13.8%
#
# Episode 470 | Avg Reward (last 100): 175.31 | Success Rate: 14.7%
#
# Episode 475 | Avg Reward (last 100): 178.67 | Success Rate: 15.6%
#
# Episode 480 | Avg Reward (last 100): 179.87 | Success Rate: 16.2%
#
# Episode 485 | Avg Reward (last 100): 181.70 | Success Rate: 17.1%
#
# Episode 490 | Avg Reward (last 100): 183.57 | Success Rate: 17.8%
#
# Episode 495 | Avg Reward (last 100): 184.91 | Success Rate: 18.4%
#
# Episode 500 | Avg Reward (last 100): 186.70 | Success Rate: 19.2%
#
# Episode 505 | Avg Reward (last 100): 188.22 | Success Rate: 20.0%
#
# Episode 510 | Avg Reward (last 100): 190.17 | Success Rate: 20.8%
#
# Episode 515 | Avg Reward (last 100): 190.41 | Success Rate: 21.6%
#
# Episode 520 | Avg Reward (last 100): 191.22 | Success Rate: 22.3%
#
# Episode 525 | Avg Reward (last 100): 191.22 | Success Rate: 23.0%
#
# Episode 530 | Avg Reward (last 100): 192.35 | Success Rate: 23.8%
#
# Episode 535 | Avg Reward (last 100): 194.58 | Success Rate: 24.5%
#
# Episode 540 | Avg Reward (last 100): 195.26 | Success Rate: 25.2%
#
# Episode 545 | Avg Reward (last 100): 196.72 | Success Rate: 25.9%
#
# Episode 550 | Avg Reward (last 100): 196.72 | Success Rate: 26.5%
#
# Episode 555 | Avg Reward (last 100): 197.47 | Success Rate: 27.2%
#
# Episode 560 | Avg Reward (last 100): 197.27 | Success Rate: 27.7%
#
# Episode 565 | Avg Reward (last 100): 197.24 | Success Rate: 28.1%
#
# Episode 570 | Avg Reward (last 100): 197.24 | Success Rate: 28.8%
#
# Episode 575 | Avg Reward (last 100): 197.24 | Success Rate: 29.4%
#
# Episode 580 | Avg Reward (last 100): 198.54 | Success Rate: 29.8%
#
# Episode 585 | Avg Reward (last 100): 198.54 | Success Rate: 30.4%
#
# Episode 590 | Avg Reward (last 100): 198.57 | Success Rate: 31.0%
#
# Episode 595 | Avg Reward (last 100): 199.49 | Success Rate: 31.6%
#
# Episode 600 | Avg Reward (last 100): 199.49 | Success Rate: 32.2%
#
# Episode 605 | Avg Reward (last 100): 199.49 | Success Rate: 32.7%
#
# Episode 610 | Avg Reward (last 100): 199.49 | Success Rate: 33.3%
#
# Episode 615 | Avg Reward (last 100): 199.28 | Success Rate: 33.7%
#
# Episode 620 | Avg Reward (last 100): 199.28 | Success Rate: 34.2%
#
# Episode 625 | Avg Reward (last 100): 199.19 | Success Rate: 34.6%
#
# Episode 630 | Avg Reward (last 100): 199.18 | Success Rate: 35.1%
#
# Episode 635 | Avg Reward (last 100): 199.17 | Success Rate: 35.6%
#
# Episode 640 | Avg Reward (last 100): 199.15 | Success Rate: 36.1%
#
# Episode 645 | Avg Reward (last 100): 199.15 | Success Rate: 36.6%
#
# Episode 650 | Avg Reward (last 100): 199.03 | Success Rate: 36.9%
#
# Episode 655 | Avg Reward (last 100): 199.03 | Success Rate: 37.4%
#
# Episode 660 | Avg Reward (last 100): 199.09 | Success Rate: 37.7%
#
# Episode 665 | Avg Reward (last 100): 199.16 | Success Rate: 38.2%
#
# Episode 670 | Avg Reward (last 100): 199.03 | Success Rate: 38.5%
#
# Episode 675 | Avg Reward (last 100): 198.89 | Success Rate: 38.8%
#
# Episode 680 | Avg Reward (last 100): 199.05 | Success Rate: 39.3%
#
# Episode 685 | Avg Reward (last 100): 198.78 | Success Rate: 39.4%
#
# Episode 690 | Avg Reward (last 100): 198.55 | Success Rate: 39.6%
#
# Episode 695 | Avg Reward (last 100): 198.35 | Success Rate: 39.9%
#
# Episode 700 | Avg Reward (last 100): 197.80 | Success Rate: 40.0%...[<Figure size 1000x500 with 1 Axes>]Final Success Rate: 40.00% (280 out of 700 episodes)
